# %% [markdown]
# # First bokeh tutorial: Basic plotting interface
# This is my first bokeh tutorial walkthrough. [Tutorial link](http://nbviewer.jupyter.org/github/bokeh/bokeh-notebooks/blob/master/tutorial/01%20-%20plotting.ipynb)

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from random import sample
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="11a74548-a4a7-42b0-a3ac-01e3c13f8189">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Basic scatter plots

# %%
# create a new plot with default tools, using figure
p = figure(plot_width=400, plot_height=400)

# add a circle renderer with a size, color, and alpha
x= range(1,6)
y = sample(range(1,11), 5)
sizes = sample(range(26,40), 5)
alpha = [x/10 for x in range(1,11,2)]
p.circle(x, y, size=sizes, line_width=2, alpha = alpha,\
         line_color=['red', 'pink', 'navy', 'black', 'white'])

# show the result
show(p)
print('x     :', list(x))
print('y     :', y)
print('sizes :', sizes)
print('alpha :', alpha)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b3497e99-7442-463c-b7ae-44414b55b31a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b3497e99-7442-463c-b7ae-44414b55b31a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b3497e99-7442-463c-b7ae-44414b55b31a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b3497e99-7442-463c-b7ae-44414b55b31a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"59a40251-b118-4ea5-b7de-8547c4c7a549":{"roots":{"references":[{"attributes":{},"id":"d48ce516-7407-4338-99c8-0b59eb7fa3c0","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"5eb981f7-d70d-44dc-bfdc-08cc4b5a152b","subtype":"Figure","type":"Plot"},"ticker":{"id":"d48ce516-7407-4338-99c8-0b59eb7fa3c0","type":"BasicTicker"}},"id":"79f3f9ce-4407-42b9-b66c-c34ee21949d0","type":"Grid"},{"attributes":{"formatter":{"id":"2ade31d7-44a1-4951-b792-ed0e4934e8a1","type":"BasicTickFormatter"},"plot":{"id":"5eb981f7-d70d-44dc-bfdc-08cc4b5a152b","subtype":"Figure","type":"Plot"},"ticker":{"id":"d48ce516-7407-4338-99c8-0b59eb7fa3c0","type":"BasicTicker"}},"id":"5d26e006-0449-4411-97df-cb5caaf1756c","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bff7d465-ce8e-435e-8e7c-9b51d0b9948d","type":"Circle"},{"attributes":{"plot":{"id":"5eb981f7-d70d-44dc-bfdc-08cc4b5a152b","subtype":"Figure","type":"Plot"}},"id":"bf1e9fdd-dbb3-4631-ada5-f37d1c63ae23","type":"PanTool"},{"attributes":{"plot":{"id":"5eb981f7-d70d-44dc-bfdc-08cc4b5a152b","subtype":"Figure","type":"Plot"}},"id":"6129bc40-f3ba-4d9c-aab1-7d328eb7f4d9","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"03cc86b4-cbd3-4104-9367-98f99af1147a","type":"BoxAnnotation"},"plot":{"id":"5eb981f7-d70d-44dc-bfdc-08cc4b5a152b","subtype":"Figure","type":"Plot"}},"id":"0dd5518d-8402-41ca-8d9e-915aa2c876a3","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"5eb981f7-d70d-44dc-bfdc-08cc4b5a152b","subtype":"Figure","type":"Plot"}},"id":"8d00db0b-e155-4367-8cf0-c240a22de0c7","type":"SaveTool"},{"attributes":{"plot":{"id":"5eb981f7-d70d-44dc-bfdc-08cc4b5a152b","subtype":"Figure","type":"Plot"}},"id":"76cb3785-c863-4640-bfe1-1ba8491af1b1","type":"ResetTool"},{"attributes":{"plot":{"id":"5eb981f7-d70d-44dc-bfdc-08cc4b5a152b","subtype":"Figure","type":"Plot"}},"id":"5e0578a7-16f2-40ff-b9b0-fe9cc68feb23","type":"HelpTool"},{"attributes":{},"id":"2f9359fa-dadf-42e4-abe4-a6eeac8def78","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"value":"#1f77b4"},"line_alpha":{"field":"line_alpha"},"line_color":{"field":"line_color"},"line_width":{"value":2},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1d7a95aa-f553-46fd-a737-1cf8fc381eb2","type":"Circle"},{"attributes":{"data_source":{"id":"2a79b873-c7e3-4ac2-b14b-1462194f4f98","type":"ColumnDataSource"},"glyph":{"id":"1d7a95aa-f553-46fd-a737-1cf8fc381eb2","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"bff7d465-ce8e-435e-8e7c-9b51d0b9948d","type":"Circle"},"selection_glyph":null},"id":"ab1cb20a-fa3e-4bdc-a194-29bc716a874e","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"26da5442-e917-476d-93c8-f465842bd1c3","type":"LinearAxis"}],"left":[{"id":"5d26e006-0449-4411-97df-cb5caaf1756c","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"26da5442-e917-476d-93c8-f465842bd1c3","type":"LinearAxis"},{"id":"dd637fd8-e9a4-4ec4-99ec-70ea7fe33aaa","type":"Grid"},{"id":"5d26e006-0449-4411-97df-cb5caaf1756c","type":"LinearAxis"},{"id":"79f3f9ce-4407-42b9-b66c-c34ee21949d0","type":"Grid"},{"id":"03cc86b4-cbd3-4104-9367-98f99af1147a","type":"BoxAnnotation"},{"id":"ab1cb20a-fa3e-4bdc-a194-29bc716a874e","type":"GlyphRenderer"}],"title":{"id":"fdf34aa3-783e-4184-a607-9fd8aa52457c","type":"Title"},"tool_events":{"id":"530fc222-7cdb-4164-99ad-f4ad70a23b29","type":"ToolEvents"},"toolbar":{"id":"884fda99-fb82-472a-b3b6-300126630c85","type":"Toolbar"},"x_range":{"id":"fa796c52-334f-4962-970f-2b081d003457","type":"DataRange1d"},"x_scale":{"id":"da5741d5-e5fc-46c5-bb10-05b91e687b9f","type":"LinearScale"},"y_range":{"id":"cae4860a-35c9-4bfc-838f-71f128bc1856","type":"DataRange1d"},"y_scale":{"id":" ...
# x     : [1, 2, 3, 4, 5]
# y     : [2, 10, 1, 4, 7]
# sizes : [39, 28, 33, 29, 35]
# alpha : [0.1, 0.3, 0.5, 0.7, 0.9]

# %%
# use radius instead of size without outline
p = figure(plot_width=400, plot_height=400)
x = range(1,6)
y = sample(range(1,11), 5)
radii = sample([x/15 for x in range(1,11)], 5)
p.circle(x, y, radius=radii, line_color='white')

# show the result
show(p)
print('x     :', list(x))
print('y     :', y)
print('radii :', [round(x, 3) for x in radii])
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5cb57a6a-9c41-4a16-9b09-bcbaaaa3ab3c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("5cb57a6a-9c41-4a16-9b09-bcbaaaa3ab3c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5cb57a6a-9c41-4a16-9b09-bcbaaaa3ab3c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5cb57a6a-9c41-4a16-9b09-bcbaaaa3ab3c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"51b400c7-17b9-442b-a114-da34b64965af":{"roots":{"references":[{"attributes":{"overlay":{"id":"2e42c4c5-f274-4ce5-b1ef-3d94d252918d","type":"BoxAnnotation"},"plot":{"id":"ced643b0-c2aa-4334-afde-4cdf6f128ca6","subtype":"Figure","type":"Plot"}},"id":"d05b8f25-9687-4574-8541-a71f0f3c215c","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"a2fda141-c43c-4dff-815a-427bcbaad578","type":"LinearAxis"}],"left":[{"id":"2b4a6eb0-0c0d-46f6-bf26-892150bd2f00","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"a2fda141-c43c-4dff-815a-427bcbaad578","type":"LinearAxis"},{"id":"56462d69-bc08-40a4-be34-0c719f6985b8","type":"Grid"},{"id":"2b4a6eb0-0c0d-46f6-bf26-892150bd2f00","type":"LinearAxis"},{"id":"fd3bc6b5-b507-42a7-8a80-16667a555b91","type":"Grid"},{"id":"2e42c4c5-f274-4ce5-b1ef-3d94d252918d","type":"BoxAnnotation"},{"id":"e18c43e6-0017-4720-a03d-abf655ed0320","type":"GlyphRenderer"}],"title":{"id":"5b8de04e-f878-4513-a657-a4401290c6d1","type":"Title"},"tool_events":{"id":"ec67e587-a38e-4477-98fe-cb0d290317d4","type":"ToolEvents"},"toolbar":{"id":"1822e252-1072-42db-8b58-95b955e412ce","type":"Toolbar"},"x_range":{"id":"59a3ccd0-a678-4606-a04c-210656713cd0","type":"DataRange1d"},"x_scale":{"id":"a82d4602-c46d-4dbe-8398-691375102708","type":"LinearScale"},"y_range":{"id":"a14a5cdc-6da0-429c-8bc4-32279f89bc41","type":"DataRange1d"},"y_scale":{"id":"510acd5d-3bc5-4524-890a-0e45148e4f57","type":"LinearScale"}},"id":"ced643b0-c2aa-4334-afde-4cdf6f128ca6","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"558637c3-0604-4ee8-afbc-6d88bbc65240","type":"BasicTicker"},{"attributes":{},"id":"ec67e587-a38e-4477-98fe-cb0d290317d4","type":"ToolEvents"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"white"},"radius":{"field":"radius","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bde502dd-7611-4843-a82a-30824f25a5dd","type":"Circle"},{"attributes":{"callback":null},"id":"59a3ccd0-a678-4606-a04c-210656713cd0","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"054c8936-e663-4450-8591-2ac61c744e9f","type":"PanTool"},{"id":"4c954c2e-8390-4d17-82cf-ae9610370229","type":"WheelZoomTool"},{"id":"d05b8f25-9687-4574-8541-a71f0f3c215c","type":"BoxZoomTool"},{"id":"135a701d-429c-46c7-a75b-fd5ba58edf48","type":"SaveTool"},{"id":"0f27beae-279f-4b06-8be3-2a6266d52e0c","type":"ResetTool"},{"id":"9bd58204-af0b-4bfa-8fcc-031992d7e907","type":"HelpTool"}]},"id":"1822e252-1072-42db-8b58-95b955e412ce","type":"Toolbar"},{"attributes":{},"id":"a82d4602-c46d-4dbe-8398-691375102708","type":"LinearScale"},{"attributes":{"data_source":{"id":"e48c3381-a4cf-4841-b72d-5b47f7a2433d","type":"ColumnDataSource"},"glyph":{"id":"bde502dd-7611-4843-a82a-30824f25a5dd","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"10338455-c34a-4fb4-b361-d669428383cf","type":"Circle"},"selection_glyph":null},"id":"e18c43e6-0017-4720-a03d-abf655ed0320","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"3c9eb1d9-dbd0-44c7-8fca-61c211749b37","type":"BasicTickFormatter"},"plot":{"id":"ced643b0-c2aa-4334-afde-4cdf6f128ca6","subtype":"Figure","type":"Plot"},"ticker":{"id":"558637c3-0604-4ee8-afbc-6d88bbc65240","type":"BasicTicker"}},"id":"a2fda141-c43c-4dff-815a-427bcbaad578","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["radius","x","y"],"data":{"radius":[0.06666666666666667,0.6,0.2,0.13333333333333333,0.4],"x":[1,2,3,4,5],"y":[3,5,1,6,4]}},"id":"e48c3381-a4cf-4841-b72d-5b47f7a2433d","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"a14a5cdc-6da0-429c-8bc4-32279f89bc41","type":"DataRange1d"},{"attributes":{"formatter":{"id":"a4aa3d31-0512-459c-9cb0-812f6765a2a6","type":"BasicTickFormatter"},"plot":{"id":"ced643b0-c2aa-4334-afde-4cdf6f128ca6","subtype":"Figure","type":"Plot"},"ticker":{"id":"d0d24fcc-a033-4d37-ad21-0734e323cc49","type":"BasicTicker" ...
# x     : [1, 2, 3, 4, 5]
# y     : [3, 5, 1, 6, 4]
# radii : [0.067, 0.6, 0.2, 0.133, 0.4]

# %%
# creating square plots
p = figure(plot_width=400, plot_height=400)

# add a square renderer with a color, alpha, and sizes
x = range(1,6)
y = sample(range(1,11),5)
sizes = sample(range(26,40), 5)
p.square(x, y, size=sizes, color='firebrick', alpha=0.7)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="08d0589c-c73f-49b1-a8b9-26511aa15b10"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("08d0589c-c73f-49b1-a8b9-26511aa15b10");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("08d0589c-c73f-49b1-a8b9-26511aa15b10");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '08d0589c-c73f-49b1-a8b9-26511aa15b10' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"dee2014e-2ce8-460b-8768-749381d925b7":{"roots":{"references":[{"attributes":{},"id":"9ec1a831-4bac-42bd-a01c-eb58b5454563","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"1266042d-7021-4d91-8495-778c55e11481","subtype":"Figure","type":"Plot"}},"id":"af226f02-e477-43c3-a18c-6e192c8c6790","type":"SaveTool"},{"attributes":{},"id":"db35b19a-b59a-4ad3-837d-9049aa528260","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8720fa23-9b05-4f80-b81b-d86572d2bf64","type":"Square"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"08775a23-846b-4a01-868d-9580733944bd","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"1266042d-7021-4d91-8495-778c55e11481","subtype":"Figure","type":"Plot"}},"id":"8d253363-d8c9-42f4-b25c-ef642ccee7f5","type":"HelpTool"},{"attributes":{"overlay":{"id":"08775a23-846b-4a01-868d-9580733944bd","type":"BoxAnnotation"},"plot":{"id":"1266042d-7021-4d91-8495-778c55e11481","subtype":"Figure","type":"Plot"}},"id":"8d22af65-a016-4d73-9af4-98d04ebdf3b4","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"1266042d-7021-4d91-8495-778c55e11481","subtype":"Figure","type":"Plot"}},"id":"3bc17eba-e524-4d36-81ad-6fe6075c7b51","type":"ResetTool"},{"attributes":{"plot":{"id":"1266042d-7021-4d91-8495-778c55e11481","subtype":"Figure","type":"Plot"}},"id":"2423e601-7bf1-4151-93da-d3a60b8702cb","type":"PanTool"},{"attributes":{"plot":{"id":"1266042d-7021-4d91-8495-778c55e11481","subtype":"Figure","type":"Plot"}},"id":"32f0e5ee-28f4-43d4-9b3a-acf00c85d8ad","type":"WheelZoomTool"},{"attributes":{"plot":null,"text":""},"id":"d0d39206-e4c7-47ba-be67-f3e679e0e2e7","type":"Title"},{"attributes":{"formatter":{"id":"db35b19a-b59a-4ad3-837d-9049aa528260","type":"BasicTickFormatter"},"plot":{"id":"1266042d-7021-4d91-8495-778c55e11481","subtype":"Figure","type":"Plot"},"ticker":{"id":"4dd85317-9f0b-4716-b911-25c8265bd865","type":"BasicTicker"}},"id":"d0dea429-bd1a-4cce-b328-d1b949e7780e","type":"LinearAxis"},{"attributes":{},"id":"4dd85317-9f0b-4716-b911-25c8265bd865","type":"BasicTicker"},{"attributes":{},"id":"b35f0029-a871-46a1-860f-4c681743d0ff","type":"LinearScale"},{"attributes":{},"id":"d5d96474-ee89-4137-b0ee-cf36e8f862fc","type":"LinearScale"},{"attributes":{"below":[{"id":"d0dea429-bd1a-4cce-b328-d1b949e7780e","type":"LinearAxis"}],"left":[{"id":"46046643-13ec-42eb-afe9-bf4bc344bafd","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"d0dea429-bd1a-4cce-b328-d1b949e7780e","type":"LinearAxis"},{"id":"d0e98dc2-e12d-4551-991e-5bf2573dcfe5","type":"Grid"},{"id":"46046643-13ec-42eb-afe9-bf4bc344bafd","type":"LinearAxis"},{"id":"b339a25f-6182-4336-9597-45bc3324a289","type":"Grid"},{"id":"08775a23-846b-4a01-868d-9580733944bd","type":"BoxAnnotation"},{"id":"41e4bfe1-bc8c-41c7-bd8b-818e9879ce6f","type":"GlyphRenderer"}],"title":{"id":"d0d39206-e4c7-47ba-be67-f3e679e0e2e7","type":"Title"},"tool_events":{"id":"574d0166-e945-43cc-a338-8d602677dee3","type":"ToolEvents"},"toolbar":{"id":"959d6125-28d4-4fb0-91d8-7168b463baa7","type":"Toolbar"},"x_range":{"id":"da823dda-51c9-47ac-981b-ed1d572fead6","type":"DataRange1d"},"x_scale":{"id":"d5d96474-ee89-4137-b0ee-cf36e8f862fc","type":"LinearScale"},"y_range":{"id":"df3e5771-3e05-425f-be52-df0735fbb2b2","type":"DataRange1d"},"y_scale":{"id":"b35f0029-a871-46a1-860f-4c681743d0ff","type":"LinearScale"}},"id":"1266042d-7021-4d91-8495-778c55e11481","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"firebrick"},"line_alpha":{"value":0 ...

# %% [markdown]
# ### Marker types available
# + [asterisk()](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.asterisk)
# + [circle()](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.circle)
# + [circle_cross()](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.circle_cross)
# + [circle_x()](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.circle_x)
# + [cross()](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.cross)
# + [diamond()](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.diamond)
# + [diamond_cross()](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.diamond_cross)
# + [inverted_triangle()](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.inverted_triangle)
# + [square()](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.square)
# + [square_cross()](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.square_cross)
# + [square_x()](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.square_x)
# + [triangle()](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.triangle)
# + [x()](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh.plotting.Figure.x)
#
# # Basic line plots

# %%
# create a new plot with a title using figure
p = figure(plot_width=400, plot_height=400, title='My line plot')

# add a line renderer
x = range(1,6)
y = sample(range(1,11), 5)
p.line(x, y, line_width=2)

# show the result
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="10dd981f-9ca2-4239-bcae-3c0df5d4fb52"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("10dd981f-9ca2-4239-bcae-3c0df5d4fb52");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("10dd981f-9ca2-4239-bcae-3c0df5d4fb52");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '10dd981f-9ca2-4239-bcae-3c0df5d4fb52' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d30e4395-1734-465b-a798-05e4993a484a":{"roots":{"references":[{"attributes":{"callback":null},"id":"639a1e63-3044-4c6f-946c-dc3087fdff0b","type":"DataRange1d"},{"attributes":{},"id":"58b20441-ff1c-4d2e-9a87-184080125240","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"59ac5795-df19-40c0-a36e-5c8cb96f2693","type":"LinearAxis"}],"left":[{"id":"bf02a05f-ea2b-491d-b463-979aa82e67ca","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"59ac5795-df19-40c0-a36e-5c8cb96f2693","type":"LinearAxis"},{"id":"acf3ebe4-6154-47d0-b00c-99eaa00918a3","type":"Grid"},{"id":"bf02a05f-ea2b-491d-b463-979aa82e67ca","type":"LinearAxis"},{"id":"5358c904-30c5-44a2-b73e-37dc40ad97a2","type":"Grid"},{"id":"105f80b6-fce6-4024-b7a8-3dc8e9a1a904","type":"BoxAnnotation"},{"id":"a504f441-732d-4ff8-b8ee-5dca291c00be","type":"GlyphRenderer"}],"title":{"id":"0671f381-6376-4d2d-839f-37d6d7d03c84","type":"Title"},"tool_events":{"id":"cb4d51a6-8d39-4fbf-ab48-dbe53ff3714b","type":"ToolEvents"},"toolbar":{"id":"326c5867-1eb6-493d-81e6-62e068a4d8ac","type":"Toolbar"},"x_range":{"id":"639a1e63-3044-4c6f-946c-dc3087fdff0b","type":"DataRange1d"},"x_scale":{"id":"beb52892-3195-4e1d-b0e6-8e8f884845e1","type":"LinearScale"},"y_range":{"id":"1802833e-cf5a-4987-8542-3a057f07a01e","type":"DataRange1d"},"y_scale":{"id":"d680fca2-8121-45c3-a627-abf25ff0b735","type":"LinearScale"}},"id":"9c114fa3-be7c-45e1-8538-be6e637cb4ef","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"9c114fa3-be7c-45e1-8538-be6e637cb4ef","subtype":"Figure","type":"Plot"}},"id":"c22bcb3e-1032-4fdd-a1df-7d83c9a20bb0","type":"PanTool"},{"attributes":{"data_source":{"id":"69fed5da-a0a0-4839-9c2f-a9e5cd688e8c","type":"ColumnDataSource"},"glyph":{"id":"c55c38dd-6cfc-4371-80c0-e1cc22f83b22","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"07b99d72-49a2-44c2-bd04-56978a78a276","type":"Line"},"selection_glyph":null},"id":"a504f441-732d-4ff8-b8ee-5dca291c00be","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c22bcb3e-1032-4fdd-a1df-7d83c9a20bb0","type":"PanTool"},{"id":"f5b845cc-0ae2-4604-9dfe-5b0f2e2fa0ce","type":"WheelZoomTool"},{"id":"52e2218b-118c-4efe-b7cd-19f23ad2739c","type":"BoxZoomTool"},{"id":"29ad7b91-af45-4ea7-908e-016c53ebed22","type":"SaveTool"},{"id":"1f15d8aa-d2e2-4393-bf5e-5ea17f04bd84","type":"ResetTool"},{"id":"366c23d1-19ae-4884-a038-7bbc857a509d","type":"HelpTool"}]},"id":"326c5867-1eb6-493d-81e6-62e068a4d8ac","type":"Toolbar"},{"attributes":{"formatter":{"id":"560a5a19-72b9-4941-a4cc-040fcb1a115c","type":"BasicTickFormatter"},"plot":{"id":"9c114fa3-be7c-45e1-8538-be6e637cb4ef","subtype":"Figure","type":"Plot"},"ticker":{"id":"1f5c472c-618b-4e46-8de0-bb15adf92476","type":"BasicTicker"}},"id":"bf02a05f-ea2b-491d-b463-979aa82e67ca","type":"LinearAxis"},{"attributes":{"plot":null,"text":"My line plot"},"id":"0671f381-6376-4d2d-839f-37d6d7d03c84","type":"Title"},{"attributes":{},"id":"d680fca2-8121-45c3-a627-abf25ff0b735","type":"LinearScale"},{"attributes":{},"id":"cb4d51a6-8d39-4fbf-ab48-dbe53ff3714b","type":"ToolEvents"},{"attributes":{"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"c55c38dd-6cfc-4371-80c0-e1cc22f83b22","type":"Line"},{"attributes":{},"id":"beb52892-3195-4e1d-b0e6-8e8f884845e1","type":"LinearScale"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"07b99d72-49a2-44c2-bd04-56978a78a276","type":"Line"},{"attributes":{"plot":{"id":"9c114fa3-be7c-45e1-8538-be6e637cb4ef","subtype":"Figure","type":"Plot"},"ticker":{"id":"ef771f81-1612-4603-ae74-80a5adce8aa4","type":"BasicTicker"}},"id":"acf3ebe4-6154-47d0-b00c-99eaa00918a3","type":"Grid"},{"attributes":{"callback":null},"id":"1802833e-cf5a-4987-8542-3a057f07a01e","type":"DataRange1d"},{"attri ...
